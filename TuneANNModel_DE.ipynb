# %% [markdown]
# <a href="https://colab.research.google.com/github/yrrSelena/RUL/blob/master/TuneANNModel_DE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import time
import numpy as np
import csv
import sys
import pandas as pd
from keras.models import Sequential, Model
from keras.layers import Dense, Input, Dropout, Reshape, Conv2D, Flatten, MaxPooling2D
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
from keras import backend as K
from keras import regularizers

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from scipy.optimize import differential_evolution
# Out:
# Using TensorFlow backend.

# %%
from data_handler_CMAPSS import CMAPSSDataHandler
from tunable_model import SequenceTunableModelRegression
import aux_functions

# %%
#K.clear_session()  #Clear the previous tensorflow graph

l2_lambda_regularization = 0.20
l1_lambda_regularization = 0.10

def RULmodel_SN(input_shape):
    #Create a sequential model
    model = Sequential()
    
    #Add the layers for the model
    model.add(Dense(20, input_dim=input_shape, activation='relu', kernel_initializer='glorot_normal', 
                    kernel_regularizer=regularizers.L1L2(l1_lambda_regularization, l2_lambda_regularization), 
                    name='fc1'))
    model.add(Dense(20, input_dim=input_shape, activation='relu', kernel_initializer='glorot_normal', 
                    kernel_regularizer=regularizers.L1L2(l1_lambda_regularization, l2_lambda_regularization), 
                    name='fc2'))
    model.add(Dense(1, activation='linear', 
                    kernel_regularizer=regularizers.L1L2(l1_lambda_regularization, l2_lambda_regularization), name='out'))
    
    return model

# %%
#Selected as per CNN paper
features = ['T2', 'T24', 'T30', 'T50', 'P2', 'P15', 'P30', 'Nf', 'Nc', 'epr', 'Ps30', 'phi', 'NRf', 'NRc', 
                     'BPR', 'farB', 'htBleed', 'Nf_dmd', 'PCNfR_dmd', 'W31', 'W32']
selected_indices = np.array([2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 17, 20, 21])
selected_features = list(features[i] for i in selected_indices-1)
data_folder = ''

window_size = 30
window_stride = 1
max_rul = 125

min_max_scaler = MinMaxScaler(feature_range=(-1, 1))

dHandler_cmaps = CMAPSSDataHandler(data_folder, 1, selected_features, max_rul, window_size, window_stride)
#dHandler_cmaps.load_data(verbose=1, cross_validation_ratio=0.2)

# %%
min_max_scaler = MinMaxScaler(feature_range=(-1, 1))

# %%
def get_compiled_model(shape, model_type='ann'):

    #Shared parameters for the models
    optimizer = Adam(lr=0, beta_1=0.5)
    lossFunction = "mean_squared_error"
    metrics = ["mse"]
    model = None

    #Create and compile the models

    if model_type=='ann':
        model = RULmodel_SN(shape)
        model.compile(optimizer = optimizer, loss = lossFunction, metrics = metrics)
    elif model_type=='lstm':
        """nFeatures = len(selected_features)
        shapeLSTM = (window_size, nFeatures)
        model = RULmodel_LSTM(shapeLSTM)
        model.compile(optimizer = optimizer, loss = lossFunction, metrics = metrics)"""
        pass
    else:
        pass

    return model

# %%
nFeatures = len(selected_features)
shapeSN = nFeatures*window_size
modelRULSN = get_compiled_model(shapeSN, model_type='ann')
tModel = SequenceTunableModelRegression('ModelRUL_SN_1', modelRULSN, lib_type='keras', data_handler=dHandler_cmaps)
#tModel = SequenceTunableModelRegression('ModelRUL_LSTM_1', modelRULLSTM, lib_type='keras', data_handler=dHandler_cmaps)
tModel.data_scaler = min_max_scaler
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
win_size = []
win_stride = []
const_rul = []
res_rmse = []
res_rhs = []

# %%
def nn_optmize_fun(x, tModel, verbose=0, epochs=250, saveToFile = None, iterations = 0):
    global win_size, win_stride, const_rul
    
    #Clear the previous tensorflow graph
    K.clear_session()
    
    maxWindowSize = {'1':30}#, '2':20, '3':30, '4':18}
    
    #Extract the tunning variables from the input vector
    #Round the values to the nearest integer since this implementation is for real numbers
    x = x.astype(int)

    #load the data using the selected parameters
    tModel.data_handler.sequence_length = x[0]
    #tModel.data_handler.sequence_length = maxWindowSize[datasetNumber]
    tModel.data_handler.sequence_stride = x[1]
    tModel.data_handler.max_rul = x[2]
    
    
    tModel.load_data(unroll=True, verbose=0, cross_validation_ratio=0, reload_data=True)
    
    if iterations == 0:
        print("Training model")
    
    
    #Create new model
    lrate = LearningRateScheduler(aux_functions.step_decay)
    nFeatures = len(selected_features)
    model_shape = nFeatures*tModel.data_handler.sequence_length
    modelRULSN = get_compiled_model(model_shape, model_type='ann')
    tModel.change_model('ModelRUL_SN_1', modelRULSN, 'keras')
    tModel.epochs = 20
    
    #Train model
    tModel.train_model(learningRate_scheduler=lrate, verbose=0)
    time = tModel.train_time
    
    if iterations == 0:
        print("Training time {}".format(time))
    
    if iterations == 0:
        print("Assesing model performance")
    #Assess the model performance
    tModel.evaluate_model(["rmse", "rhs"], round=2)
    
    
    cScores = tModel.scores
    rmse = cScores['rmse']
    rhs = cScores['rhs']
    #print("The score for this model is: {}".format(rmse))
    
    print(x)
    print(rmse)
    print(rhs)
    #print('------hhh333---')
    msgStr = "The model variables are " + str(x)# + "\tThe scores are: [RMSE:{:.4f}, RHS:{:.4f}]\n".format(rmse, rhs)
    print(msgStr)
    #print('------hhh333---')
    row = x.tolist() + [rmse, rhs]
    
    win_size.append(x[0])
    win_stride.append(x[1])
    const_rul.append(x[2])
    res_rmse.append(rmse)
    res_rhs.append(rhs)
    
    #print('------hhh---')
    if saveToFile is not None:
        #print(msgStr)
        writer = csv.writer(saveToFile)
        #row = x.append(rmse)
        #row = x.append(rhs)
        writer.writerow(row)
        #saveToFile.write(msgStr)
    else:
        print(row)
    
    #print('------hhh1---')
    #Return RMSE as the performance metric to steer the search
    return rmse

# %%
#Optimize the parameters for the NN using DE

#maxWindowSize = {'1':30, '2':20, '3':30, '4':18}
maxWindowSize = {'1':30} #Do it only for datasets 1 and 2
totalTime = {'1':0}#, '2':0, '3':0, '4':0}
results = {'1':0}#, '2':0, '3':0, '4':0}

#datasetNumber = '1'

selected_features = ['T24', 'T30', 'T50', 'P30', 'Nf', 'Nc', 'Ps30', 'phi', 'NRf', 'NRc', 
                     'BPR', 'htBleed', 'W31', 'W32']



for datasetNumber in maxWindowSize:
    
    print("Tunning for dataset "+datasetNumber)
    file = open(str(datasetNumber)+"_res.csv", "w")

    windowSizeBounds = [1,maxWindowSize[datasetNumber]]
    windowStrideBounds = [1,10]
    constantRULBounds = [90,140]

    bounds = [windowSizeBounds, windowStrideBounds, constantRULBounds]
    #bounds = [windowStrideBounds, constantRULBounds] #Optimize only 2 variabes
    
    tModel.data_handler.change_dataset(datasetNumber)
    
    startTime = time.clock()
    
    tempResults = differential_evolution(nn_optmize_fun, bounds, 
                                     args=(tModel, 0, 20, file, 1),
                                    strategy='best1bin', maxiter=30, popsize=4, disp=True, polish=False)
    results[datasetNumber] = tempResults
    endTime = time.clock()

    file.close()
    totalTime[datasetNumber] = endTime - startTime
# Out:
# Tunning for dataset 1
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 552us/step
# [ 20   7 117]
# 32.151049749580494
# [32.42443845]
# The model variables are [ 20   7 117]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 612us/step
# [ 10   9 135]
# 42.9150323313405
# [104.60685687]
# The model variables are [ 10   9 135]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 547us/step
# [ 27   7 129]
# 31.36239786751007
# [31.18423131]
# The model variables are [ 27   7 129]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 605us/step
# [ 17   2 121]
# 21.063000735887563
# [20.56986433]
# The model variables are [ 17   2 121]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 473us/step
# [11  5 92]
# 37.390774263178876
# [51.81520012]
# The model variables are [11  5 92]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 460us/step
# [ 22   6 102]
# 24.276943794472977
# [10.75742043]
# The model variables are [ 22   6 102]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 559us/step
# [  5   4 138]
# 31.321398436212903
# [33.21758461]
# The model variables are [  5   4 138]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 586us/step
# [  7   9 100]
# 44.688924802460846
# [104.77687101]
# The model variables are [  7   9 100]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 590us/step
# [14  1 95]
# 23.402350309317224
# [9.70481392]
# The model variables are [14  1 95]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 497us/step
# [  2   2 107]
# 22.22431101294256
# [8.77107305]
# The model variables are [  2   2 107]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 610us/step
# [ 23   6 123]
# 34.57744929863971
# [45.91468671]
# The model variables are [ 23   6 123]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 522us/step
# [ 25   3 112]
# 20.403431084011338
# [12.75463026]
# The model variables are [ 25   3 112]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 526us/step
# [ 9  6 90]
# 32.25151159248199
# [26.71322115]
# The model variables are [ 9  6 90]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 557us/step
# [ 17   9 135]
# 34.40639475446388
# [45.99299362]
# The model variables are [ 17   9 135]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 545us/step
# [ 22   2 116]
# 20.177958271341527
# [16.06821629]
# The model variables are [ 22   2 116]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 510us/step
# [ 14   3 109]
# 21.93308003906428
# [11.65923223]
# The model variables are [ 14   3 109]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 499us/step
# [ 9  7 92]
# 51.24851217352558
# [197.13889163]
# The model variables are [ 9  7 92]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 537us/step
# [10  3 94]
# 24.057846952709628
# [11.00278014]
# The model variables are [10  3 94]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 577us/step
# [ 25   9 111]
# 32.00078124046349
# [30.44628313]
# The model variables are [ 25   9 111]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 559us/step
# [  7   3 136]
# 21.62036077404815
# [17.95084535]
# The model variables are [  7   3 136]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 549us/step
# [21  1 95]
# 22.623439172681064
# [7.80654421]
# The model variables are [21  1 95]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 563us/step
# [ 10   1 134]
# 20.455072720476945
# [18.38840322]
# The model variables are [ 10   1 134]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 576us/step
# [ 13   5 123]
# 27.101106988460824
# [17.67916482]
# The model variables are [ 13   5 123]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 562us/step
# [ 22   4 103]
# 23.4222116803687
# [11.79910394]
# The model variables are [ 22   4 103]
# differential_evolution step 1: f(x)= 20.178
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 542us/step
# [17  4 92]
# 25.326468368092698
# [13.17405605]
# The model variables are [17  4 92]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 560us/step
# [ 15   4 135]
# 23.665798106127756
# [14.3213925]
# The model variables are [ 15   4 135]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 546us/step
# [  8   3 134]
# 21.501162759255603
# [11.34639464]
# The model variables are [  8   3 134]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 640us/step
# [ 17   1 121]
# 17.934882213162147
# [7.48710465]
# The model variables are [ 17   1 121]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 528us/step
# [ 27   2 128]
# 17.233687939614086
# [5.78755842]
# The model variables are [ 27   2 128]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 502us/step
# [ 10   3 135]
# 21.279332696304177
# [22.34365842]
# The model variables are [ 10   3 135]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 524us/step
# [ 20   1 138]
# 18.342846016908062
# [8.9550219]
# The model variables are [ 20   1 138]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 555us/step
# [ 21   5 129]
# 23.057970422394074
# [12.03102211]
# The model variables are [ 21   5 129]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 547us/step
# [ 12   1 104]
# 21.89703176231884
# [10.94601707]
# The model variables are [ 12   1 104]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 534us/step
# [ 24   1 113]
# 16.504241878983716
# [3.7237579]
# The model variables are [ 24   1 113]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 591us/step
# [ 23   3 105]
# 21.086014322294293
# [10.43538489]
# The model variables are [ 23   3 105]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 562us/step
# [ 29   4 116]
# 21.820861577857094
# [16.60443621]
# The model variables are [ 29   4 116]
# differential_evolution step 2: f(x)= 16.5042
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 607us/step
# [ 24   2 107]
# 20.361483246561384
# [8.3651303]
# The model variables are [ 24   2 107]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 585us/step
# [ 17   3 135]
# 21.860695322884858
# [23.23166151]
# The model variables are [ 17   3 135]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 534us/step
# [ 23   4 135]
# 22.224985939253145
# [20.1531902]
# The model variables are [ 23   4 135]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 550us/step
# [ 22   3 101]
# 22.569669913403697
# [11.7931792]
# The model variables are [ 22   3 101]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 563us/step
# [ 17   1 113]
# 18.50027026829608
# [6.12495167]
# The model variables are [ 17   1 113]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 555us/step
# [ 26   3 113]
# 20.559912451175467
# [11.37911525]
# The model variables are [ 26   3 113]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 603us/step
# [ 20   1 138]
# 17.986661724733693
# [7.60149441]
# The model variables are [ 20   1 138]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 561us/step
# [ 10   9 104]
# 40.631391804859454
# [78.0706854]
# The model variables are [ 10   9 104]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 516us/step
# [ 22   5 125]
# 24.747323087558378
# [14.03458049]
# The model variables are [ 22   5 125]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 536us/step
# [ 22   2 111]
# 19.180719485983836
# [6.74167916]
# The model variables are [ 22   2 111]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 524us/step
# [ 27   3 116]
# 20.51925924588897
# [11.40393264]
# The model variables are [ 27   3 116]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 591us/step
# [  2   1 122]
# 19.567319693816014
# [12.0423316]
# The model variables are [  2   1 122]
# differential_evolution step 3: f(x)= 16.5042
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 603us/step
# [ 24   2 113]
# 18.427696546231708
# [6.30203632]
# The model variables are [ 24   2 113]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 565us/step
# [ 25   7 122]
# 24.910841013502534
# [12.69433046]
# The model variables are [ 25   7 122]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 567us/step
# [ 23   4 111]
# 21.673716801693242
# [15.32896503]
# The model variables are [ 23   4 111]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 531us/step
# [ 19   2 117]
# 20.613587751771888
# [10.04084444]
# The model variables are [ 19   2 117]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 478us/step
# [ 27   2 112]
# 18.469434208984314
# [5.81799171]
# The model variables are [ 27   2 112]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 554us/step
# [ 22   3 118]
# 20.298768435548006
# [13.75399442]
# The model variables are [ 22   3 118]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 585us/step
# [ 19   1 124]
# 17.455944546199728
# [5.80282436]
# The model variables are [ 19   1 124]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 616us/step
# [ 22   1 114]
# 17.21307642462555
# [4.24279495]
# The model variables are [ 22   1 114]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 553us/step
# [ 21   1 104]
# 19.406184581210187
# [5.09397092]
# The model variables are [ 21   1 104]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 566us/step
# [ 23   2 120]
# 19.25305170615817
# [10.96679363]
# The model variables are [ 23   2 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 588us/step
# [ 27   1 105]
# 17.438749955200343
# [4.0246799]
# The model variables are [ 27   1 105]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 553us/step
# [  2   1 122]
# 19.18254414826146
# [10.99082519]
# The model variables are [  2   1 122]
# differential_evolution step 4: f(x)= 16.5042
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 519us/step
# [ 18   4 124]
# 22.06399782451041
# [11.58156496]
# The model variables are [ 18   4 124]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 517us/step
# [ 20   4 135]
# 21.873957117997648
# [15.09687991]
# The model variables are [ 20   4 135]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 587us/step
# [ 25   3 120]
# 20.516578662145402
# [15.1154598]
# The model variables are [ 25   3 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 575us/step
# [ 24   2 114]
# 17.515421776251923
# [4.7136203]
# The model variables are [ 24   2 114]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 539us/step
# [ 17   1 121]
# 18.742731924668828
# [8.35322828]
# The model variables are [ 17   1 121]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 592us/step
# [ 22   3 122]
# 19.755505561741515
# [13.43933965]
# The model variables are [ 22   3 122]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 593us/step
# [27  9 93]
# 45.318428922459354
# [131.28535317]
# The model variables are [27  9 93]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 549us/step
# [13  9 97]
# 45.92646295982306
# [134.01080095]
# The model variables are [13  9 97]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 533us/step
# [ 18   3 134]
# 21.734304681769785
# [26.38258117]
# The model variables are [ 18   3 134]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 487us/step
# [  5   1 113]
# 20.14174768981083
# [10.36889424]
# The model variables are [  5   1 113]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 541us/step
# [ 27   3 133]
# 19.60382615715616
# [12.3309498]
# The model variables are [ 27   3 133]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 457us/step
# [  2   1 104]
# 20.710866712911848
# [8.13856388]
# The model variables are [  2   1 104]
# differential_evolution step 5: f(x)= 16.5042
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 574us/step
# [ 24   1 113]
# 16.38596960817394
# [3.61901438]
# The model variables are [ 24   1 113]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 587us/step
# [ 23   3 114]
# 21.10758157629623
# [13.61091706]
# The model variables are [ 23   3 114]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 543us/step
# [ 21   5 120]
# 23.698312176186725
# [11.4356338]
# The model variables are [ 21   5 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 522us/step
# [ 27   9 114]
# 31.548217065311313
# [28.12501463]
# The model variables are [ 27   9 114]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 564us/step
# [ 26   3 121]
# 20.045697792793344
# [11.74861108]
# The model variables are [ 26   3 121]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 607us/step
# [ 22   1 122]
# 17.03613806001818
# [4.6278557]
# The model variables are [ 22   1 122]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 600us/step
# [ 19   2 112]
# 19.881398341163028
# [9.39134839]
# The model variables are [ 19   2 112]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 540us/step
# [ 18   6 120]
# 30.777426793024787
# [27.73580539]
# The model variables are [ 18   6 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 602us/step
# [ 24   2 104]
# 19.66799430546999
# [6.02756797]
# The model variables are [ 24   2 104]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 553us/step
# [ 25   1 128]
# 15.676415406590882
# [3.66856672]
# The model variables are [ 25   1 128]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 578us/step
# [ 22   1 134]
# 17.168867172880102
# [5.41476301]
# The model variables are [ 22   1 134]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 497us/step
# [  2   1 118]
# 19.73702105182036
# [9.64303933]
# The model variables are [  2   1 118]
# differential_evolution step 6: f(x)= 15.6764
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 552us/step
# [ 25   6 120]
# 22.690085940780392
# [10.90677243]
# The model variables are [ 25   6 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 561us/step
# [ 22   1 114]
# 17.620442673213407
# [4.22202882]
# The model variables are [ 22   1 114]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 524us/step
# [ 25   1 119]
# 16.119863522995473
# [3.81073428]
# The model variables are [ 25   1 119]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 584us/step
# [ 25   1 114]
# 16.492725669215503
# [3.65165083]
# The model variables are [ 25   1 114]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 553us/step
# [ 26   1 129]
# 15.911316727411343
# [4.11373394]
# The model variables are [ 26   1 129]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 596us/step
# [ 22   1 107]
# 18.76166303929372
# [5.14108995]
# The model variables are [ 22   1 107]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 560us/step
# [ 23   1 129]
# 16.47149052150412
# [4.45131697]
# The model variables are [ 23   1 129]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 531us/step
# [ 23   1 129]
# 16.10620998248812
# [4.14304401]
# The model variables are [ 23   1 129]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 596us/step
# [ 21   4 135]
# 23.807561823924768
# [14.40004891]
# The model variables are [ 21   4 135]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 590us/step
# [ 22   1 115]
# 16.689517668285085
# [4.32310202]
# The model variables are [ 22   1 115]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 532us/step
# [ 22   1 120]
# 16.736487086602136
# [4.16519727]
# The model variables are [ 22   1 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 552us/step
# [  2   1 128]
# 19.576005721290542
# [14.09211395]
# The model variables are [  2   1 128]
# differential_evolution step 7: f(x)= 15.6764
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 606us/step
# [ 12   1 139]
# 21.86664126014784
# [26.41045481]
# The model variables are [ 12   1 139]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 701us/step
# [ 24   1 123]
# 15.517731793016658
# [3.54897874]
# The model variables are [ 24   1 123]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 591us/step
# [ 25   1 133]
# 16.20277753966893
# [4.3061738]
# The model variables are [ 25   1 133]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 500us/step
# [ 22   1 114]
# 17.362315513778686
# [4.10875216]
# The model variables are [ 22   1 114]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 521us/step
# [ 25   1 129]
# 15.720687007888682
# [3.74034742]
# The model variables are [ 25   1 129]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 591us/step
# [ 23   1 121]
# 16.741863695538797
# [4.19063896]
# The model variables are [ 23   1 121]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 570us/step
# [ 23   6 127]
# 25.507645912549435
# [14.67677933]
# The model variables are [ 23   6 127]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 570us/step
# [ 22   1 110]
# 18.217025004099874
# [4.90019177]
# The model variables are [ 22   1 110]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 523us/step
# [ 26   1 104]
# 18.318842758209374
# [4.40312399]
# The model variables are [ 26   1 104]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 516us/step
# [  9   6 121]
# 33.70741758129804
# [40.72890621]
# The model variables are [  9   6 121]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 556us/step
# [ 24   2 127]
# 17.835918815693237
# [7.39999221]
# The model variables are [ 24   2 127]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 576us/step
# [ 22   1 127]
# 17.527121840165314
# [6.31071977]
# The model variables are [ 22   1 127]
# differential_evolution step 8: f(x)= 15.5177
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 577us/step
# [ 26   1 122]
# 16.18888507587845
# [3.86985392]
# The model variables are [ 26   1 122]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 608us/step
# [23  1 93]
# 22.008634669147472
# [7.0783265]
# The model variables are [23  1 93]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 544us/step
# [ 26   1 130]
# 16.58583733189253
# [4.8887578]
# The model variables are [ 26   1 130]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 546us/step
# [ 23   1 114]
# 16.97615975419647
# [3.90289133]
# The model variables are [ 23   1 114]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 534us/step
# [ 25   1 103]
# 18.159570479501987
# [4.34334862]
# The model variables are [ 25   1 103]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 558us/step
# [ 23   1 114]
# 16.3180881233066
# [3.67042278]
# The model variables are [ 23   1 114]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 573us/step
# [ 23   1 109]
# 17.946866021676318
# [4.51358209]
# The model variables are [ 23   1 109]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 554us/step
# [ 25   1 115]
# 16.430763828866873
# [3.76109478]
# The model variables are [ 25   1 115]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 544us/step
# [ 26   1 104]
# 18.804786624686813
# [4.76267251]
# The model variables are [ 26   1 104]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 587us/step
# [ 26   1 126]
# 15.967466924969658
# [3.95584918]
# The model variables are [ 26   1 126]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 543us/step
# [ 25   1 125]
# 15.589098755219943
# [3.51276957]
# The model variables are [ 25   1 125]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 543us/step
# [ 22   2 128]
# 17.934324631833785
# [7.89747475]
# The model variables are [ 22   2 128]
# differential_evolution step 9: f(x)= 15.5177
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 589us/step
# [ 24   1 128]
# 17.39425192412712
# [6.13883729]
# The model variables are [ 24   1 128]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 560us/step
# [ 24   1 122]
# 15.988120589988055
# [3.65666998]
# The model variables are [ 24   1 122]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 615us/step
# [ 23   1 123]
# 16.096272860510286
# [3.93008764]
# The model variables are [ 23   1 123]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 578us/step
# [ 24   1 114]
# 17.152550830707366
# [4.32085939]
# The model variables are [ 24   1 114]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 542us/step
# [ 25   1 110]
# 17.143803545304642
# [4.12699355]
# The model variables are [ 25   1 110]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 538us/step
# [ 24   1 123]
# 16.008747608729422
# [3.61254416]
# The model variables are [ 24   1 123]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 581us/step
# [ 23   1 125]
# 16.209565077447326
# [3.88186664]
# The model variables are [ 23   1 125]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 585us/step
# [ 24   1 129]
# 15.84455742518547
# [3.91323328]
# The model variables are [ 24   1 129]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 552us/step
# [ 23   1 122]
# 15.90943116519255
# [3.53139018]
# The model variables are [ 23   1 122]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 577us/step
# [ 26   1 126]
# 16.69281282468596
# [4.81686793]
# The model variables are [ 26   1 126]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 495us/step
# [ 25   1 117]
# 16.470276257549536
# [3.72825715]
# The model variables are [ 25   1 117]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 556us/step
# [ 25   1 123]
# 15.761027885261798
# [3.52303169]
# The model variables are [ 25   1 123]
# differential_evolution step 10: f(x)= 15.5177
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 646us/step
# [ 24   1 123]
# 15.718778578502848
# [3.52379126]
# The model variables are [ 24   1 123]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 544us/step
# [ 25   1 123]
# 15.599038431903423
# [3.48788778]
# The model variables are [ 25   1 123]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 577us/step
# [ 22   1 120]
# 16.46754383628597
# [4.01583525]
# The model variables are [ 22   1 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 577us/step
# [ 23   1 121]
# 16.416455159382004
# [3.79869]
# The model variables are [ 23   1 121]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 531us/step
# [ 24   1 122]
# 15.824348327814324
# [3.42605166]
# The model variables are [ 24   1 122]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 580us/step
# [ 24   1 123]
# 15.752460125326456
# [3.56851583]
# The model variables are [ 24   1 123]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 520us/step
# [ 23   1 119]
# 16.357567056258702
# [3.72244832]
# The model variables are [ 23   1 119]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 538us/step
# [ 24   1 129]
# 15.848028268526026
# [4.00095702]
# The model variables are [ 24   1 129]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 555us/step
# [ 23   1 124]
# 16.00718588634492
# [3.8968527]
# The model variables are [ 23   1 124]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 520us/step
# [ 26   1 120]
# 16.603614064413808
# [3.90305397]
# The model variables are [ 26   1 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 507us/step
# [ 24   1 127]
# 15.803797012110728
# [3.78681072]
# The model variables are [ 24   1 127]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 526us/step
# [ 25   1 124]
# 15.759758881404245
# [3.41146449]
# The model variables are [ 25   1 124]
# differential_evolution step 11: f(x)= 15.5177
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 521us/step
# [ 26   1 120]
# 16.747238578344792
# [4.06071784]
# The model variables are [ 26   1 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 483us/step
# [ 25   1 123]
# 15.75499920660106
# [3.47537109]
# The model variables are [ 25   1 123]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 530us/step
# [ 25   1 122]
# 15.854652314068575
# [3.38067492]
# The model variables are [ 25   1 122]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 563us/step
# [ 23   1 121]
# 16.18054387219416
# [3.69322555]
# The model variables are [ 23   1 121]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 573us/step
# [ 25   1 120]
# 15.921997362140216
# [3.43951223]
# The model variables are [ 25   1 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 482us/step
# [ 25   1 119]
# 15.4483008774428
# [3.22972551]
# The model variables are [ 25   1 119]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 529us/step
# [ 26   1 125]
# 16.52876280911551
# [4.5427797]
# The model variables are [ 26   1 125]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 569us/step
# [ 24   1 121]
# 16.098136538121423
# [3.61090183]
# The model variables are [ 24   1 121]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 540us/step
# [ 23   1 116]
# 16.73618833546038
# [3.85256293]
# The model variables are [ 23   1 116]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 554us/step
# [ 24   1 126]
# 15.67545852598896
# [3.85188269]
# The model variables are [ 24   1 126]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 487us/step
# [ 27   1 125]
# 16.168487869927727
# [4.59021495]
# The model variables are [ 27   1 125]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 528us/step
# [ 25   1 124]
# 15.544130725132236
# [3.46326156]
# The model variables are [ 25   1 124]
# differential_evolution step 12: f(x)= 15.4483
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 548us/step
# [ 26   1 120]
# 16.443843832875572
# [4.38888112]
# The model variables are [ 26   1 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 502us/step
# [ 25   1 119]
# 15.956816725149162
# [3.42713979]
# The model variables are [ 25   1 119]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 542us/step
# [ 25   1 122]
# 15.680561214446376
# [3.36060316]
# The model variables are [ 25   1 122]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 468us/step
# [ 25   1 120]
# 15.606729317829537
# [3.50145099]
# The model variables are [ 25   1 120]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 515us/step
# [ 25   1 115]
# 18.69786084021378
# [6.97151146]
# The model variables are [ 25   1 115]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 505us/step
# [ 26   1 123]
# 16.197221984031707
# [4.15458144]
# The model variables are [ 26   1 123]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 556us/step
# [ 25   1 125]
# 15.551205741035002
# [3.37348722]
# The model variables are [ 25   1 125]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 528us/step
# [ 26   1 119]
# 16.558985476169727
# [3.71745507]
# The model variables are [ 26   1 119]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 478us/step
# [ 26   1 117]
# 17.208428167616006
# [4.2595796]
# The model variables are [ 26   1 117]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 538us/step
# [ 25   1 126]
# 15.565988564816564
# [3.62503277]
# The model variables are [ 25   1 126]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 508us/step
# [ 25   1 122]
# 16.231758992789416
# [4.21161428]
# The model variables are [ 25   1 122]
# Reloading data per user's request
# training without cv
# 100/100 [==============================] - 0s 491us/step
# [ 25   1 122]
# 15.905973720586866
# [3.57868242]
# The model variables are [ 25   1 122]
# differential_evolution step 13: f(x)= 15.4483
